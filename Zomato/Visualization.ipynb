# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import squarify
from scipy.stats import norm
plt.style.use("ggplot")

# %%
df = pd.read_csv("cleaned.csv")
df['approx_cost'] = df['approx_cost'].astype("float32")
df['rating'] = df['rating'].astype("float32")
df['rating_count'] = df['rating_count'].astype("int32")
df.head(2)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address            name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...           Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice Elephant
#
#   online_order book_table  rating  rating_count  \
# 0          Yes        Yes     4.1           775
# 1          Yes         No     4.1           787
#
#                                 phone      location      rest_type  \
# 0  ['080 42297555', '+91 9743772233']  Banashankari  Casual Dining
# 1                    ['080 41714161']  Banashankari  Casual Dining
#
#                                            specialty  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines  approx_cost  \
# 0  North Indian, Mughlai, Chinese        400.0
# 1     Chinese, North Indian, Thai        400.0
#
#                                              reviews     menu    type  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...  No Menu  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...  No Menu  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   url           51717 non-null  object
#  1   address       51717 non-null  object
#  2   name          51717 non-null  object
#  3   online_order  51717 non-null  object
#  4   book_table    51717 non-null  object
#  5   rating        51717 non-null  float32
#  6   rating_count  51717 non-null  int32
#  7   phone         51717 non-null  object
#  8   location      51717 non-null  object
#  9   rest_type     51717 non-null  object
#  10  specialty     51717 non-null  object
#  11  cuisines      51717 non-null  object
#  12  approx_cost   51717 non-null  float32
#  13  reviews       51717 non-null  object
#  14  menu          51717 non-null  object
#  15  type          51717 non-null  object
#  16  city          51717 non-null  object
# dtypes: float32(2), int32(1), object(14)
# memory usage: 6.1+ MB

# %%
df.describe()
# Out:
#              rating  rating_count   approx_cost
# count  51717.000000  51717.000000  51717.000000
# mean       3.700362    283.697527    276.861328
# std        0.395391    803.838853    218.937805
# min        1.800000      0.000000     20.000000
# 25%        3.500000      7.000000    150.000000
# 50%        3.700000     41.000000    200.000000
# 75%        3.900000    198.000000    325.000000
# max        4.900000  16832.000000   3000.000000

# %%
df.describe(include=["object","bool"])
# Out:
#                                                       url        address  \
# count                                               51717          51717
# unique                                              51717          11495
# top     https://www.zomato.com/bangalore/the-nest-the-...  Delivery Only
# freq                                                    1            128
#
#                    name online_order book_table            phone location  \
# count             51717        51717      51717            51717    51717
# unique             8792            2          2            14927       94
# top     Cafe Coffee Day          Yes         No  No Contect Info      BTM
# freq                 96        30444      45268             1208     5124
#
#           rest_type      specialty      cuisines reviews     menu      type  \
# count         51717          51717         51717   51717    51717     51717
# unique           94           5272          2724   22513     9098         7
# top     Quick Bites  Not Mentioned  North Indian      []  No Menu  Delivery
# freq          19132          28078          2913    7595    39617     25942
#
#          city
# count   51717
# unique     30
# top       BTM
# freq     3279

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Rating Gaussian Distribution

# %%
Rating = df[['rating']].sort_values(by='rating')
plt.figure(figsize=(12,4))
plt.plot(Rating, norm.pdf(Rating, Rating.mean(), Rating.std()),
         label=f"mean: {np.round(Rating.mean(),2).values}\nstd: {np.round(Rating.std().values,2)}")
plt.title("Gaussian Distribution Of Rating")
plt.xlabel("Ratings")
plt.ylabel("Probability Dencity")
plt.legend()
plt.show()

# %% [markdown]
# ## Restaurants delivering Online or not

# %%
def Pie_NumData(x):
    return f'{x:.1f}%\n{int(df.shape[0]*x/100)} Rest.'

# %%
def text_edit(bar,upper, lower, total):
    plt.text(bar,(upper+lower)/2,f'{round((upper-lower)/total*100,1)}%',ha='center')

# %%
plt.pie(df["online_order"].value_counts(),
        labels=df["online_order"].unique(),
        autopct=lambda pct: Pie_NumData(pct),
        shadow=True,
        wedgeprops={
            "edgecolor":"black",
            "linewidth":1,
            "antialiased": True
        })
plt.title("Online Delivery Facility")
plt.show()

# %%
No = df[['online_order','rating']][df['online_order']=='No'].copy()
Yes = df[['online_order','rating']][df['online_order']=='Yes'].copy()

# %%
plt.figure(figsize=(12,6))
plt.bar(No['online_order'],
        No['rating'][No['rating']<=3].count(),
        color='#9e0142', label='Low Rating')

plt.bar(No['online_order'],
        No['rating'][(No['rating']<=4) & (No['rating']>3)].count(),
        bottom=No['rating'][No['rating']<=3].count(),color='#d53e4f',label='Avg Rating')
text_edit(0,
          No['rating'][(No['rating']<=4)].count(),
          No['rating'][No['rating']<=3].count(),
          No.rating.count())

plt.bar(No['online_order'],
        No['rating'][No['rating']>4].count(),
        bottom=(No['rating'][No['rating']<=4].count()),
        color='#f46d43',
        label='Heigh Rating')
text_edit(0,
          No['rating'].count(),
          No['rating'][(No['rating']<=4)].count(),
          No.rating.count())



plt.bar(Yes['online_order'],
        Yes['rating'][Yes['rating']<=3].count(),
        color='#9e0142')

plt.bar(Yes['online_order'],
        Yes['rating'][(Yes['rating']<=4) & (Yes['rating']>3)].count(),
        bottom=Yes['rating'][Yes['rating']<=3].count(),color='#d53e4f')
text_edit(1,
          Yes['rating'][(Yes['rating']<=4)].count(),
          Yes['rating'][Yes['rating']<=3].count(),
          Yes.rating.count())

plt.bar(Yes['online_order'],
        Yes['rating'][Yes['rating']>4].count(),
        bottom=(Yes['rating'][Yes['rating']<=4].count()),
        color='#f46d43')
text_edit(1, Yes['rating'].count(), Yes['rating'][Yes['rating']<=4].count(), Yes.rating.count())


plt.title("Effects of Online Order Facility over Rating")
plt.legend(loc='upper left')
plt.show()
del Yes, No

# %% [markdown]
# ## Restaurants allowing table booking or not

# %%
df['book_table'].unique()[::-1]
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
plt.pie(df['book_table'].value_counts(),
       autopct= lambda pct: Pie_NumData(pct),
       labels=df['book_table'].unique()[::-1],
       shadow=True,
       wedgeprops={
           'edgecolor':"black",
           'linewidth':1,
           'antialiased':True
       })
plt.title("Advance Table Booking")
plt.show()

# %%
No = df[['book_table','rating']][df['book_table']=='No'].copy()
Yes = df[['book_table','rating']][df['book_table']=='Yes'].copy()

# %%
plt.figure(figsize=(12,6))
plt.bar(No['book_table'],
        No['rating'][No['rating']<=3].count(),
        color='#9e0142', label='Low Rating')
text_edit(0, No['rating'][No['rating']<=3].count(),
          0, No.rating.count())

plt.bar(No['book_table'],
        No['rating'][(No['rating']<=4) & (No['rating']>3)].count(),
        bottom=No['rating'][No['rating']<=3].count(),color='#d53e4f',label='Avg Rating')
text_edit(0,
          No['rating'][(No['rating']<=4)].count(),
          No['rating'][No['rating']<=3].count(),
          No.rating.count())

plt.bar(No['book_table'],
        No['rating'][No['rating']>4].count(),
        bottom=(No['rating'][No['rating']<=4].count()),
        color='#f46d43',
        label='Heigh Rating')
text_edit(0,
          No['rating'].count(),
          No['rating'][(No['rating']<=4)].count(),
          No.rating.count())



plt.bar(Yes['book_table'],
        Yes['rating'][Yes['rating']<=3].count(),
        color='#9e0142')

plt.bar(Yes['book_table'],
        Yes['rating'][(Yes['rating']<=4) & (Yes['rating']>3)].count(),
        bottom=Yes['rating'][Yes['rating']<=3].count(),color='#d53e4f')
text_edit(1,
          Yes['rating'][(Yes['rating']<=4)].count(),
          Yes['rating'][Yes['rating']<=3].count(),
          Yes.rating.count())

plt.bar(Yes['book_table'],
        Yes['rating'][Yes['rating']>4].count(),
        bottom=(Yes['rating'][Yes['rating']<=4].count()),
        color='#f46d43')
text_edit(1, Yes['rating'].count(), Yes['rating'][Yes['rating']<=4].count(), Yes.rating.count())


plt.title("Effects of Advance Table Booking Facility over Rating")
plt.legend(loc='upper right')
plt.show()
del Yes, No

# %% [markdown]
# ## Best Location

# %%
locations = df[['location','rating']].groupby('location')
Avg_rating = locations.mean()
Avg_rating = Avg_rating.sort_values('rating', ascending=False)

# %%
plt.figure(figsize=(12,4))

sns.barplot(x='rating',y=Avg_rating.index[:15],data=Avg_rating[:15])
sns.despine(left=True,bottom=True)

plt.xlabel("Ratings\nBest locations based on Avg. ration of Restaurants")
plt.ylabel("Locations")
plt.title("Top 15 Location")
plt.show()

# %% [markdown]
# ## No. of restaurants in a Location

# %%
loc_count = locations.count().sort_values('rating',ascending=False)
loc_count.rename(columns={'rating':'Restaurents'},inplace=True)

# %%
plt.figure(figsize=(12,4))

sns.barplot(x='Restaurents',y=loc_count.index[:15],data=loc_count[:15])
sns.despine(left=True,bottom=True)

plt.xlabel("Restaurents Count\nBest locations based on Number of Restaurants Located")
plt.ylabel("Locations")
plt.title("15 Most Populated Location")
plt.show()

# %% [markdown]
# ## Relation between Location and Rating
# * by comparing best laction to last restaurant in the list

# %%
top_res = Avg_rating.index[0]
bottom_res = Avg_rating.index[-1]

# %%
f, ax = plt.subplots(1, 2, figsize=(12,4))
sns.boxplot(x=df['location'][df['location']==top_res],
            y=df['rating'][df['location']==top_res],
            data=df, ax=ax[0])

sns.boxplot(x=df['location'][df['location']==bottom_res],
            y=df['rating'][df['location']==bottom_res],
            data=df, ax=ax[1])

ax[0].set(ylim=(2.5,5), xlabel='Location', ylabel='Rating', title="Top Restaurants")
ax[1].set(ylim=(2.5,5), xlabel='Location', ylabel='Rating', title="Bottom List Restaurants")

plt.suptitle("Top Vs Low Point Restaurants Location")
plt.show()

# %% [markdown]
# ## Restaurant

# %% [markdown]
# * Types and it's relation with rating

# %% [markdown]
# ### Types

# %%
rest_typ_g = df[['rest_type','rating']].groupby('rest_type')
rest_typ = pd.DataFrame(rest_typ_g['rest_type'].value_counts())
rest_typ = rest_typ.sort_values('count', ascending=False)

# %%
plt.figure(figsize=(13,6))
squarify.plot(sizes=rest_typ['count'][:10],label=rest_typ.index[:10],
              color=['#9e0142','#d53e4f','#f46d43','#fdae61','#fee08b','#e6f598','#abdda4','#66c2a5','#3288bd','#5e4fa2'])
plt.title('10 Most Common Restaurant Type')
plt.show()

# %% [markdown]
# ### Impact in Rating

# %%
def top_tupe_condition(col:str,end:int,data_group):
    if data_group.count()['count']<end:
        end = data_group.count()['count']
    condition = (df[col]==data_group.index[0])
    for coun in range(1,end):
        condition = condition | (df[col]==data_group.index[coun])
    return condition

# %%
plt.figure(figsize=(12,6))
condition = top_tupe_condition(col='rest_type',end=10,data_group=rest_typ)
sns.boxplot(x=df['rest_type'][condition],
            y=df['rating'],
            data=df[condition])
plt.title("Relation Between Restaurant Type And Rating")
plt.xlabel("Restaurant Type")
plt.xticks(rotation=80)
plt.ylabel("Rating")
plt.show()

# %% [markdown]
# ## Services

# %% [markdown]
# * Types and it's relation with Ratings

# %% [markdown]
# ### Types

# %%
services_type_g = df[['type','rating']].groupby('type')
services_type = pd.DataFrame(services_type_g['type'].value_counts())
services_type = services_type.sort_values('count', ascending=False)

# %%
plt.figure(figsize=(13,6))
services_type.index = services_type.index.str.replace("& ","&\n")
squarify.plot(sizes=services_type['count'], label=services_type.index,
             color=['#9e0142','#d53e4f','#f46d43','#fdae61','#fee08b','#e6f598','#abdda4'])
plt.title("Most Common Services Offered")
plt.show()

# %% [markdown]
# ### Impact In Rating

# %%
plt.figure(figsize=(12,6))
condition = top_tupe_condition(col='type',end=10, data_group=services_type)
sns.boxplot(x=df['type'][condition],
            y=df['rating'],
            data=df[condition])
plt.title("Relation Between Services Type And Rating")
plt.xlabel("Services Type")
plt.ylabel("Rating")
plt.show()

# %% [markdown]
# ## Cost of Restaurant

# %% [markdown]
# ### Average Approx Cost By Location

# %%
cost_by_Location = df[['location', 'approx_cost']][df['location'] != 'Not Found'].groupby(by='location')
mean_cost = pd.DataFrame(cost_by_Location['approx_cost'].mean())
mean_cost = mean_cost.sort_values(by='approx_cost')
print("5 Most chip locations")
print(mean_cost.head(5), end="\n\n\n")
print("5 Most Expensive Loactions")
print(mean_cost.tail(5)[::-1])
# Out:
# 5 Most chip locations
#                 approx_cost
# location
# Peenya           150.000000
# City Market      151.174606
# Yelahanka        154.166672
# CV Raman Nagar   155.555557
# Ejipura          160.136673
#
#
# 5 Most Expensive Loactions
#                   approx_cost
# location
# Sankey Road       1252.777832
# Race Course Road   654.676270
# Lavelle Road       648.251404
# MG Road            566.666687
# Infantry Road      531.125854

# %% [markdown]
# ### Approx Average Cost By Restaurant Type

# %%
cost_by_res_type = df[['rest_type', 'approx_cost']][df['rest_type'] != 'Not Found'].groupby(by='rest_type')
mean_res_type = pd.DataFrame(cost_by_res_type['approx_cost'].mean())
mean_res_type = mean_res_type.sort_values(by='approx_cost')
print("5 Most chip Restaurant Type")
print(mean_res_type.head(5), end="\n\n\n")
print("5 Most Expensive Restaurent Type")
print(mean_res_type.tail(5)[::-1])
# Out:
# 5 Most chip Restaurant Type
#                             approx_cost
# rest_type
# Dessert Parlor, Food Court      50.0000
# Sweet Shop, Dessert Parlor      50.0000
# Bakery, Beverage Shop           89.0625
# Dessert Parlor, Kiosk          100.0000
# Food Court, Beverage Shop      100.0000
#
#
# 5 Most Expensive Restaurent Type
#                            approx_cost
# rest_type
# Fine Dining, Bar           1501.250000
# Fine Dining, Microbrewery  1500.000000
# Fine Dining, Lounge        1500.000000
# Fine Dining                1353.757202
# Bar, Lounge                1225.000000

# %% [markdown]
# ## Most famous restaurant chains in Bengaluru

# %%
df['bengaluru'] = df['address'].apply(lambda adrs: True if 'bengaluru' in adrs.lower() else False)
rest_in_bangaluru = df[['rest_type','rating']][df['bengaluru']==True]

bangaluru_rest_typ_g = rest_in_bangaluru[['rest_type','rating']].groupby('rest_type')
bangaluru_rest_typ = pd.DataFrame(bangaluru_rest_typ_g['rating'].mean())
bangaluru_rest_typ = bangaluru_rest_typ.sort_values('rating', ascending=False)

# %%
plt.figure(figsize=(13,6))
squarify.plot(sizes=bangaluru_rest_typ['rating'][:10],label=bangaluru_rest_typ.index[:10],
              color=['#9e0142','#d53e4f','#f46d43','#fdae61','#fee08b','#e6f598','#abdda4','#66c2a5','#3288bd','#5e4fa2'])
plt.title('10 Most Famous Restaurant Chains in Bengaluru')
plt.show()
